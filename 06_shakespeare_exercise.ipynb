# %% [markdown]
# # Exercise: Find correspondences between old and modern english

# %% [markdown]
# The purpose of this execise is to use two vecsigrafos, one built on UMBC and Wordnet and another one produced by directly running Swivel against a corpus of Shakespeare's complete works, to try to find corelations between old and modern English, e.g. "thou" -> "you", "dost" -> "do", "raiment" -> "clothing". For example, you can try to pick a set of 100 words in "ye olde" English corpus and see how they correlate to UMBC over WordNet.
#
# ![William Shaespeare](https://github.com/HybridNLP2018/tutorial/blob/master/images/220px-Shakespeare.jpg?raw=1)

# %% [markdown]
# Next, we prepare the embeddings from the Shakespeare corpus and load a UMBC vecsigrafo, which will provide the two vector spaces to correlate.

# %% [markdown]
# ## Download a small text corpus

# %% [markdown]
# First, we download the corpus into our environment. We will use the Shakespeare's complete works corpus, published as part of Project Gutenberg and pbublicly available.

# %%
import os

# %%
# %ls
# Out:
# sample_data/  tutorial/

# %%
#!rm -r tutorial
# !git clone https://github.com/hybridnlp/tutorial
# Out:
# fatal: destination path 'tutorial' already exists and is not an empty directory.

# %% [markdown]
# Let us see if the corpus is where we think it is:

# %%
# %cd tutorial/lit
# %ls
# Out:
# /content/tutorial/lit
# coocs/  shakespeare_complete_works.txt  swivel/  tutorial/  vec/

# %% [markdown]
# Downloading Swivel

# %%
# !wget http://hybridnlp.expertsystemlab.com/tutorial/swivel.zip
# !unzip swivel.zip
# !rm swivel/*
# !rm swivel.zip
# Out:
# --2019-11-19 01:18:31--  http://hybridnlp.expertsystemlab.com/tutorial/swivel.zip
# Resolving hybridnlp.expertsystemlab.com (hybridnlp.expertsystemlab.com)... 217.126.74.30
# Connecting to hybridnlp.expertsystemlab.com (hybridnlp.expertsystemlab.com)|217.126.74.30|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35964 (35K) [application/zip]
# Saving to: ‘swivel.zip’
#
# swivel.zip          100%[===================>]  35.12K   138KB/s    in 0.3s
#
# 2019-11-19 01:18:31 (138 KB/s) - ‘swivel.zip’ saved [35964/35964]
#
# Archive:  swivel.zip
#   inflating: swivel/analogy.cc
#   inflating: swivel/distributed.sh
#   inflating: swivel/eval.mk
#   inflating: swivel/fastprep.cc
#   inflating: swivel/fastprep.mk
#   inflating: swivel/glove_to_shards.py
#   inflating: swivel/nearest.py
#   inflating: swivel/prep.py
#   inflating: swivel/README.md
#   inflating: swivel/swivel.py
#   inflating: swivel/text2bin.py
#   inflating: swivel/vecs.py
#   inflating: swivel/wordsim.py

# %% [markdown]
# ## Learn the Swivel embeddings over the Old Shakespeare corpus

# %% [markdown]
# ### Calculating the co-occurrence matrix

# %%
corpus_path = '/content/tutorial/lit/shakespeare_complete_works.txt'
coocs_path = '/content/tutorial/lit/coocs'
shard_size = 512
freq=3
# !python /content/tutorial/scripts/swivel/prep.py --input={corpus_path} --output_dir={coocs_path} --shard_size={shard_size} --min_count={freq}
# Out:
# WARNING:tensorflow:From /content/tutorial/scripts/swivel/prep.py:324: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# running with flags
# /content/tutorial/scripts/swivel/prep.py:
#   --bufsz: The number of co-occurrences to buffer
#     (default: '16777216')
#     (an integer)
#   --input: The input text.
#     (default: '')
#   --max_vocab: The maximum vocabulary size
#     (default: '1048576')
#     (an integer)
#   --min_count: The minimum number of times a word should occur to be included in
#     the vocabulary
#     (default: '5')
#     (an integer)
#   --output_dir: Output directory for Swivel data
#     (default: '/tmp/swivel_data')
#   --shard_size: The size for each shard
#     (default: '4096')
#     (an integer)
#   --vocab: Vocabulary to use instead of generating one
#     (default: '')
#   --window_size: The window size
#     (default: '10')
#     (an integer)
#
# absl.app:
#   -?,--[no]help: show this help
#     (default: 'false')
#   --[no]helpfull: show full help
#     (default: 'false')
#   --[no]helpshort: show this help
#     (default: 'false')
#   --[no]helpxml: like --helpfull, but generates XML output
#     (default: 'false')
#   --[no]only_check_args: Set to true to validate args and exit.
#     (default: 'false')
#   --[no]pdb_post_mortem: Set to true to handle uncaught exceptions with PDB post
#     mortem.
#     (default: 'false')
#   --profile_file: Dump profile information to a file (for python -m pstats).
#     Implies --run_with_profiling.
#   --[no]run_with_pdb: Set to true for PDB debug mode
#     (default: 'false')
#   --[no]run_with_profiling: Set to true for profiling the script. Execution will
#     be slower, and the output format might change over time.
#     (default: 'false')
#   --[no]use_cprofile_for_profiling: Use cProfile instead of the profile module
#     for profiling. This has no effect unless --run_with_profiling is set.
#     (default: 'true')
#
# absl.logging:
#   --[no]alsologtostderr: also log to stderr?
#     (default: 'false')
#   --log_dir: directory to write logfiles into
#     (default: '')
#   --[no]logtostderr: Should only log to stderr?
#     (default: 'false')
#   --[no]showprefixforinfo: If False, do not prepend prefix to info messages when
#     it's logged to stderr, --verbosity is set to INFO level, and python logging
#     is used.
#     (default: 'true')
#   --stderrthreshold: log messages at this level, or more severe, to stderr in
#     addition to the logfile.  Possible values are 'debug', 'info', 'warning',
#     'error', and 'fatal'.  Obsoletes --alsologtostderr. Using --alsologtostderr
#     cancels the effect of this flag. Please also note that this flag is subject
#     to --verbosity and requires logfile not be stderr.
#     (default: 'fatal')
#   -v,--verbosity: Logging verbosity level. Messages logged at this level or
#     lower will be included. Set to 1 for debug logging. If the flag was not set
#     or supplied, the value will be changed from the default of -1 (warning) to 0
#     (info) after flags are parsed.
#     (default: '-1')
#     (an integer)
#
# absl.testing.absltest:
#   --test_random_seed: Random seed for testing. Some test frameworks may change
#     the default value of this flag between runs, so it is not appropriate for
#     seeding probabilistic tests.
#     (default: '301')
#     (an integer)
#   --test_randomize_ordering_seed: If positive, use this as a seed to randomize
#     the execution order for test cases. If "random", pick a random seed to use.
#     If 0 or not set, do not randomize test case execution order. This flag also
#     overrides the TEST_RANDOMIZE_ORDERING_SEED environment variable.
#   --test_srcdir: Root of directory tree where source files live
#     (default: '')
#   --test_tmpdir: Directory for temporary testing files
#     (default: '/tmp/absl_testing')
#   --xml_output_file: File to store XML test results
#     (default: '')
#
# tensorflow.python.ops.parallel_for.pfor:
#   --[no]op_conversion_fallback_to_while_loop: If true, falls back to using a
#     while loop for ops for which a converter is not defined.
#     (default: 'false')
#
# absl.flags:
#   --flagfile: Insert flag definitions from the given file into the command line.
#     (default: '')
#   --undefok: comma-separated list of flag names that it is okay to specify on
#     the command line even if the program does not define a flag with that name.
#     IMPORTANT: flags in this list that have arguments MUST use the --flag=value
#     format.
#     (default: '')
#
# vocabulary contains 23552 tokens
# Computing co-occurrences: 140000..., last lid 1820, sum(1820)=188.256746
# writing shard 2116/2116
# Wrote vocab and sum files to /content/tutorial/lit/coocs
# Wrote vocab and sum files to /content/tutorial/lit/coocs
# done!

# %%
# %ls {coocs_path} | head -n 10
# Out:
# col_sums.txt
# col_vocab.txt
# row_sums.txt
# row_vocab.txt
# shard-000-000.pb
# shard-000-001.pb
# shard-000-002.pb
# shard-000-003.pb
# shard-000-004.pb
# shard-000-005.pb

# %% [markdown]
# ### Learning the embeddings from the matrix

# %%
vec_path = '/content/tutorial/lit/vec/'
# !python /content/tutorial/scripts/swivel/swivel.py --input_base_path={coocs_path} \
    --output_base_path={vec_path} \
    --num_epochs=20 --dim=300 \
    --submatrix_rows={shard_size} --submatrix_cols={shard_size}
# Out:
# WARNING:tensorflow:From /content/tutorial/scripts/swivel/swivel.py:523: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/tutorial/scripts/swivel/swivel.py:418: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W1119 01:18:58.410995 139851149072256 module_wrapper.py:139] From /content/tutorial/scripts/swivel/swivel.py:418: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /content/tutorial/scripts/swivel/swivel.py:418: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W1119 01:18:58.411242 139851149072256 module_wrapper.py:139] From /content/tutorial/scripts/swivel/swivel.py:418: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From /content/tutorial/scripts/swivel/swivel.py:455: The name tf.train.replica_device_setter is deprecated. Please use tf.compat.v1.train.replica_device_setter instead.
#
# W1119 01:18:58.411523 139851149072256 module_wrapper.py:139] From /content/tutorial/scripts/swivel/swivel.py:455: The name tf.train.replica_device_setter is deprecated. Please use tf.compat.v1.train.replica_device_setter instead.
#
# WARNING:tensorflow:From /content/tutorial/scripts/swivel/swivel.py:255: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# W1119 01:18:58.470022 139851149072256 deprecation.py:323] From /content/tutorial/scripts/swivel/swivel.py:255: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:277: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# W1119 01:18:58.482430 139851149072256 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:277: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:189: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# W1119 01:18:58.483428 139851149072256 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:189: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:198: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W1119 01:18:58.485180 139851149072256 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:198: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:198: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W1119 01:18:58.487137 139851149072256 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:198: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /content/tutorial/scripts/swivel/swivel.py:256: WholeFileReader.__init__ (from tensorflow.python.ops.io_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.map(tf.read_file)`.
# W1119 01:18:58.491397 139851149072256 deprecation.py:323] From /content/tutorial/scripts/swivel/swivel.py:256: WholeFileReader.__init__ (from tensorflow.python.ops.io_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.map(tf.read_file)`.
# WARNING:tensorflow:From /content/tutorial/scripts/swivel/swivel.py:258: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# W1119 01:18:58.493372 139851149072256 module_wrapper.py:139] From /content/tutorial/scripts/swivel/swivel.py:258: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# WARNING:tensorflow:From /content/tutorial/scripts/swivel/swivel.py:261: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# W1119 01:18:58.493658 139851149072256 module_wrapper.py:139] From /content/tutorial/scripts/swivel/swivel.py:261: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# WARNING:tensorflow:From /content/tutorial/scripts/swivel/swivel.py:263: The name tf.VarLenFeature is deprecated. Please use tf.io.VarLenFeature instead.
#
# W1119 01:18:58.493979 139851149072256 module_wrapper.py:139] From /content/tutorial/scripts/swivel/swivel.py:263: The name tf.VarLenFeature is deprecated. Please use tf.io.VarLenFeature instead.
#
# WARNING:tensorflow:From /content/tutorial/scripts/swivel/swivel.py:280: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1119 01:18:58.500941 139851149072256 deprecation.py:323] From /content/tutorial/scripts/swivel/swivel.py:280: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /content/tutorial/scripts/swivel/swivel.py:147: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W1119 01:18:58.502939 139851149072256 module_wrapper.py:139] From /content/tutorial/scripts/swivel/swivel.py:147: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/tutorial/scripts/swivel/swivel.py:174: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1119 01:18:58.625682 139851149072256 deprecation.py:323] From /content/tutorial/scripts/swivel/swivel.py:174: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/tutorial/scripts/swivel/swivel.py:177: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W1119 01:18:58.627667 139851149072256 module_wrapper.py:139] From /content/tutorial/scripts/swivel/swivel.py:177: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/tutorial/scripts/swivel/swivel.py:226: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# W1119 01:18:58.657385 139851149072256 module_wrapper.py:139] From /content/tutorial/scripts/swivel/swivel.py:226: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W1119 01:18:58.778597 139851149072256 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /content/tutorial/scripts/swivel/swivel.py:485: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W1119 01:18:58.820485 139851149072256 module_wrapper.py:139] From /content/tutorial/scripts/swivel/swivel.py:485: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/tutorial/scripts/swivel/swivel.py:495: Supervisor.__init__ (from tensorflow.python.training.supervisor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.MonitoredTrainingSession
# W1119 01:18:58.825214 139851149072256 deprecation.py:323] From /content/tutorial/scripts/swivel/swivel.py:495: Supervisor.__init__ (from tensorflow.python.training.supervisor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.MonitoredTrainingSession
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1119 01:18:58.847451 139851149072256 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:Issue encountered when serializing global_step.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'Tensor' object has no attribute 'to_proto'
# W1119 01:18:58.881941 139851149072256 meta_graph.py:448] Issue encountered when serializing global_step.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'Tensor' object has no attribute 'to_proto'
# 2019-11-19 01:18:58.884897: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-11-19 01:18:58.903538: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-19 01:18:58.904273: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-11-19 01:18:58.904558: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2019-11-19 01:18:58.906278: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2019-11-19 01:18:58.908859: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2019-11-19 01:18:58.909326: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2019-11-19 01:18:58.914376: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2019-11-19 01:18:58.916163: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2019-11-19 01:18:58.922172: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-11-19 01:18:58.923765: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-19 01:18:58.926692: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-19 01:18:58.927580: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-11-19 01:18:58.934182: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-11-19 01:18:58.934425: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2fcabc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2019-11
# INFO:tensorflow:local_step=42210 global_step=42210 loss=18.4, 99.7% complete
# I1119 01:24:30.754214 139851149072256 swivel.py:513] local_step=42210 global_step=42210 loss=18.4, 99.7% complete
# INFO:tensorflow:local_step=42220 global_step=42220 loss=15.2, 99.8% complete
# I1119 01:24:30.832837 139851149072256 swivel.py:513] local_step=42220 global_step=42220 loss=15.2, 99.8% complete
# INFO:tensorflow:local_step=42230 global_step=42230 loss=19.6, 99.8% complete
# I1119 01:24:30.908777 139851149072256 swivel.py:513] local_step=42230 global_step=42230 loss=19.6, 99.8% complete
# INFO:tensorflow:local_step=42240 global_step=42240 loss=18.8, 99.8% complete
# I1119 01:24:30.982269 139851149072256 swivel.py:513] local_step=42240 global_step=42240 loss=18.8, 99.8% complete
# INFO:tensorflow:local_step=42250 global_step=42250 loss=18.2, 99.8% complete
# I1119 01:24:31.063637 139851149072256 swivel.py:513] local_step=42250 global_step=42250 loss=18.2, 99.8% complete
# INFO:tensorflow:local_step=42260 global_step=42260 loss=19.1, 99.9% complete
# I1119 01:24:31.149499 139851149072256 swivel.py:513] local_step=42260 global_step=42260 loss=19.1, 99.9% complete
# INFO:tensorflow:local_step=42270 global_step=42270 loss=18.7, 99.9% complete
# I1119 01:24:31.224674 139851149072256 swivel.py:513] local_step=42270 global_step=42270 loss=18.7, 99.9% complete
# INFO:tensorflow:local_step=42280 global_step=42280 loss=18.2, 99.9% complete
# I1119 01:24:31.306686 139851149072256 swivel.py:513] local_step=42280 global_step=42280 loss=18.2, 99.9% complete
# INFO:tensorflow:local_step=42290 global_step=42290 loss=18.1, 99.9% complete
# I1119 01:24:31.383632 139851149072256 swivel.py:513] local_step=42290 global_step=42290 loss=18.1, 99.9% complete
# INFO:tensorflow:local_step=42300 global_step=42300 loss=18.6, 100.0% complete
# I1119 01:24:31.457717 139851149072256 swivel.py:513] local_step=42300 global_step=42300 loss=18.6, 100.0% complete
# INFO:tensorflow:local_step=42310 global_step=42310 loss=18.1, 100.0% complete
# I1119 01:24:31.534203 139851149072256 swivel.py:513] local_step=42310 global_step=42310 loss=18.1, 100.0% complete
# INFO:tensorflow:local_step=42320 global_step=42320 loss=19.0, 100.0% complete
# I1119 01:24:31.620048 139851149072256 swivel.py:513] local_step=42320 global_step=42320 loss=19.0, 100.0% complete
# WARNING:tensorflow:Issue encountered when serializing global_step.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'Tensor' object has no attribute 'to_proto'
# W1119 01:24:31.914883 139851149072256 meta_graph.py:448] Issue encountered when serializing global_step.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'Tensor' object has no attribute 'to_proto'

# %% [markdown]
# Checking the context of the 'vec' directory. Should contain checkpoints of the model plus tsv files for column and row embeddings.

# %%
os.listdir(vec_path)
# Out:
# ['row_embedding.tsv',
#  'model.ckpt-42320.meta',
#  'model.ckpt-0.index',
#  'checkpoint',
#  'events.out.tfevents.1574126130.82d727d3ce6b',
#  'model.ckpt-0.meta',
#  'graph.pbtxt',
#  'events.out.tfevents.1574126339.82d727d3ce6b',
#  'model.ckpt-42320.index',
#  'model.ckpt-0.data-00000-of-00001',
#  'events.out.tfevents.1574125900.82d727d3ce6b',
#  'model.ckpt-42320.data-00000-of-00001',
#  'col_embedding.tsv']

# %% [markdown]
# Converting tsv to bin:

# %%
# !python /content/tutorial/scripts/swivel/text2bin.py --vocab={vec_path}vocab.txt --output={vec_path}vecs.bin \
        {vec_path}row_embedding.tsv \
        {vec_path}col_embedding.tsv
# Out:
# executing text2bin
# merging files ['/content/tutorial/lit/vec/row_embedding.tsv', '/content/tutorial/lit/vec/col_embedding.tsv'] into output bin

# %%
# %ls {vec_path}
# Out:
# checkpoint
# col_embedding.tsv
# events.out.tfevents.1574125900.82d727d3ce6b
# events.out.tfevents.1574126130.82d727d3ce6b
# events.out.tfevents.1574126339.82d727d3ce6b
# graph.pbtxt
# model.ckpt-0.data-00000-of-00001
# model.ckpt-0.index
# model.ckpt-0.meta
# model.ckpt-42320.data-00000-of-00001
# model.ckpt-42320.index
# model.ckpt-42320.meta
# row_embedding.tsv
# vecs.bin
# vocab.txt

# %% [markdown]
# ### Read stored binary embeddings and inspect them

# %%
import importlib.util

spec = importlib.util.spec_from_file_location("vecs", "/content/tutorial/scripts/swivel/vecs.py")
m = importlib.util.module_from_spec(spec)
spec.loader.exec_module(m)
shakespeare_vecs = m.Vecs(vec_path + 'vocab.txt', vec_path + 'vecs.bin')
# Out:
# Opening vector with expected size 23552 from file /content/tutorial/lit/vec/vocab.txt
# vocab size 23552 (unique 23552)
# read rows

# %% [markdown]
# ##Basic method to print the k nearest neighbors for a given word

# %%
def k_neighbors(vec, word, k=10):
    res = vec.neighbors(word)
    if not res:
        print('%s is not in the vocabulary, try e.g. %s' % (word, vecs.random_word_in_vocab()))
    else:
        for word, sim in res[:10]:
            print('%0.4f: %s' % (sim, word))

# %%
k_neighbors(shakespeare_vecs, 'strife')
# Out:
# 1.0000: strife
# 0.3432: War
# 0.3359: strokes
# 0.3301: tutors
# 0.3171: future
# 0.3039: tumultuous
# 0.3024: daughters’
# 0.2861: nature.
# 0.2773: strike.
# 0.2582: fellows

# %%
k_neighbors(shakespeare_vecs,'youth')
# Out:
# 1.0000: youth
# 0.3293: ignorance;
# 0.3152: northern
# 0.2891: tall,
# 0.2831: womb;
# 0.2797: Sicily
# 0.2793: vanity,
# 0.2765: tall
# 0.2693: idleness.
# 0.2652: violet

# %% [markdown]
# ## Load vecsigrafo from UMBC over WordNet

# %%
# %ls
# Out:
# coocs/  shakespeare_complete_works.txt  swivel/  tutorial/  vec/

# %%
# !wget https://zenodo.org/record/1446214/files/vecsigrafo_umbc_tlgs_ls_f_6e_160d_row_embedding.tar.gz
# %ls
# Out:
# --2019-11-19 01:24:54--  https://zenodo.org/record/1446214/files/vecsigrafo_umbc_tlgs_ls_f_6e_160d_row_embedding.tar.gz
# Resolving zenodo.org (zenodo.org)... 188.184.65.20
# Connecting to zenodo.org (zenodo.org)|188.184.65.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1166454112 (1.1G) [application/octet-stream]
# Saving to: ‘vecsigrafo_umbc_tlgs_ls_f_6e_160d_row_embedding.tar.gz’
#
# vecsigrafo_umbc_tlg 100%[===================>]   1.09G  24.2MB/s    in 51s
#
# 2019-11-19 01:25:46 (21.8 MB/s) - ‘vecsigrafo_umbc_tlgs_ls_f_6e_160d_row_embedding.tar.gz’ saved [1166454112/1166454112]
#
# coocs/
# shakespeare_complete_works.txt
# swivel/
# tutorial/
# vec/
# vecsigrafo_umbc_tlgs_ls_f_6e_160d_row_embedding.tar.gz

# %%
# !tar -xvzf vecsigrafo_umbc_tlgs_ls_f_6e_160d_row_embedding.tar.gz
# !rm vecsigrafo_umbc_tlgs_ls_f_6e_160d_row_embedding.tar.gz
# Out:
# vecsi_tlgs_wnscd_ls_f_6e_160d/row_embedding.tsv

# %%
umbc_wn_vec_path = '/content/tutorial/lit/vecsi_tlgs_wnscd_ls_f_6e_160d/'

# %% [markdown]
# Extracting the vocabulary from the .tsv file:

# %%
with open(umbc_wn_vec_path + 'vocab.txt', 'w', encoding='utf_8') as f:
  with open(umbc_wn_vec_path + 'row_embedding.tsv', 'r', encoding='utf_8') as vec_lines:
    vocab = [line.split('\t')[0].strip() for line in vec_lines]
    for word in vocab:
      print(word, file=f)

# %% [markdown]
# Converting tsv to bin:

# %%
# !python /content/tutorial/scripts/swivel/text2bin.py --vocab={umbc_wn_vec_path}vocab.txt --output={umbc_wn_vec_path}vecs.bin \
        {umbc_wn_vec_path}row_embedding.tsv
# Out:
# executing text2bin
# merging files ['/content/tutorial/lit/vecsi_tlgs_wnscd_ls_f_6e_160d/row_embedding.tsv'] into output bin

# %%
# %ls
# Out:
# coocs/                          swivel/    vec/
# shakespeare_complete_works.txt  tutorial/  vecsi_tlgs_wnscd_ls_f_6e_160d/

# %%
umbc_wn_vecs = m.Vecs(umbc_wn_vec_path + 'vocab.txt', umbc_wn_vec_path + 'vecs.bin')
# Out:
# Opening vector with expected size 1499136 from file /content/tutorial/lit/vecsi_tlgs_wnscd_ls_f_6e_160d/vocab.txt
# vocab size 1499136 (unique 1499125)
# read rows

# %%
k_neighbors(umbc_wn_vecs, 'lem_California')
# Out:
# 1.0000: lem_California
# 0.6301: lem_Central Valley
# 0.5959: lem_University of California
# 0.5542: lem_Southern California
# 0.5254: lem_Santa Cruz
# 0.5241: lem_Astro Aerospace
# 0.5168: lem_San Francisco Bay
# 0.5092: lem_San Diego County
# 0.5074: lem_Santa Barbara
# 0.5069: lem_Santa Rosa

# %% [markdown]
# # Add your solution to the proposed exercise here

# %% [markdown]
# Follow the instructions given in the previous lesson (*Vecsigrafos for curating and interlinking knowledge graphs*) to find correlation between terms in old Enlgish extracted from the Shakespeare corpus and terms in modern English extracted from UMBC. You will need to generate a dictionary relating pairs of lemmas between the two vocabularies and use to produce a pair of translation matrices to transform vectors from one vector space to the other. Then apply the k_neighbors method to identify the correlations.

# %% [markdown]
# # Conclusion

# %% [markdown]
# This notebook proposes the use of Shakespeare's complete works and UMBC to provide the student with embeddings that can be exploited for different operations between the two vector spaces. Particularly, we propose to identify terms and their correlations over such spaces.

# %% [markdown]
# # Acknowledgements

# %% [markdown]
# In memory of Dr. Jack Brandabur, whose passion for Shakespeare and Cervantes inspired this notebook.
